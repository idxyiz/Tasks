# %% [markdown]
# # Dataset Description

# %% [markdown]
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ## 1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("Task (1) Dataset.csv")

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
df.head(20)
# Out:
#         Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0   17:02:00      Monday              18-30          Male   Above high school
# 1   17:02:00      Monday              31-50          Male  Junior high school
# 2   17:02:00      Monday              18-30          Male  Junior high school
# 3    1:06:00      Sunday              18-30          Male  Junior high school
# 4    1:06:00      Sunday              18-30          Male  Junior high school
# 5   14:15:00      Friday              31-50          Male                 NaN
# 6   17:30:00   Wednesday              18-30          Male  Junior high school
# 7   17:20:00      Friday              18-30          Male  Junior high school
# 8   17:20:00      Friday              18-30          Male  Junior high school
# 9   17:20:00      Friday              18-30          Male  Junior high school
# 10  14:40:00    Saturday              18-30          Male   Above high school
# ...

# %%
df["Educational_level"] = df["Educational_level"].fillna(value=df["Educational_level"].mode()[0])
df["Vehicle_driver_relation"] = df["Vehicle_driver_relation"].fillna(value=df["Vehicle_driver_relation"].mode()[0])
df["Driving_experience"] = df["Driving_experience"].fillna(value=df["Driving_experience"].mode()[0])
df["Type_of_vehicle"] = df["Type_of_vehicle"].fillna(value=df["Type_of_vehicle"].mode()[0])
df["Owner_of_vehicle"] = df["Owner_of_vehicle"].fillna(value=df["Owner_of_vehicle"].mode()[0])
df["Service_year_of_vehicle"] = df["Service_year_of_vehicle"].fillna(value=df["Service_year_of_vehicle"].mode()[0])
df["Defect_of_vehicle"] = df["Defect_of_vehicle"].fillna(value=df["Defect_of_vehicle"].mode()[0])
df["Area_accident_occured"] = df["Area_accident_occured"].fillna(value=df["Area_accident_occured"].mode()[0])
df["Lanes_or_Medians"] = df["Lanes_or_Medians"].fillna(value=df["Lanes_or_Medians"].mode()[0])
df["Road_allignment"] = df["Road_allignment"].fillna(value=df["Road_allignment"].mode()[0])
df["Types_of_Junction"] = df["Types_of_Junction"].fillna(value=df["Types_of_Junction"].mode()[0])
df["Road_surface_type"] = df["Road_surface_type"].fillna(value=df["Road_surface_type"].mode()[0])
df["Type_of_collision"] = df["Type_of_collision"].fillna(value=df["Type_of_collision"].mode()[0])
df["Vehicle_movement"] = df["Vehicle_movement"].fillna(value=df["Vehicle_movement"].mode()[0])
df["Fitness_of_casuality"] = df["Fitness_of_casuality"].fillna(value=df["Fitness_of_casuality"].mode()[0])

# %%
#change unknown value
x= df["Age_band_of_driver"].mode()[0]
df["Age_band_of_driver"] =df["Age_band_of_driver"].replace("Unknown",x)

# %%
x1= df["Sex_of_casualty"].mode()[0]
df["Sex_of_casualty"] =df["Sex_of_casualty"].replace(pd.NA,x1)

# %%
x2= df["Casualty_class"].mode()[0]
df["Casualty_class"] =df["Casualty_class"].replace(pd.NA,x2)

# %%
df["Age_band_of_casualty"] = df["Age_band_of_casualty"].replace("na",x)

# %%
x3= df["Casualty_severity"].mode()[0]
df["Casualty_severity"] =df["Casualty_severity"].replace(pd.NA,x3)

# %%
#x4= df["Work_of_casuality"].mode()[0]
df["Work_of_casuality"] = df["Work_of_casuality"].replace(pd.NA,"Employee")

# %%
df.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0 2024-07-25 17:02:00      Monday              18-30          Male
# 1 2024-07-25 17:02:00      Monday              31-50          Male
# 2 2024-07-25 17:02:00      Monday              18-30          Male
# 3 2024-07-25 01:06:00      Sunday              18-30          Male
# 4 2024-07-25 01:06:00      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0           Automobile            Owner              Above 10yr  ...
# ...

# %%
df.isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Correct any inconsistent data entries
#
# - values out of the ordinary?
# - mixed-case (captial and small)?
# - units?
# - ...etc.

# %%
# I found inconsistent DateTime data, the same exact Date for various week days

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# - numerical but object?
# - date but object?
# - ...etc.

# %%
df['Time'] = pd.to_datetime(df['Time'],format='mixed')

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 2
#       1 df.describe()
# ----> 2 x.agg()
#
# File c:\Python312\Lib\site-packages\pandas\core\frame.py:10148, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10144 from pandas.core.apply import frame_apply
#   10146 axis = self._get_axis_number(axis)
# > 10148 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
#   10149 result = op.agg()
#   10150 result = reconstruct_and_relabel_result(result, func, **kwargs)
#
# File c:\Python312\Lib\site-packages\pandas\core\apply.py:102, in frame_apply(obj, func, axis, raw, result_type, by_row, engine, engine_kwargs, args, kwargs)
#      99 elif axis == 1:
#     100     klass = FrameColumnApply
# --> 102 _, func, _, _ = reconstruct_func(func, **kwargs)
#     103 assert func is not None
#     105 return klass(
#     106     obj,
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data
#
# - heatmap

# %%
xx = df.sort_values(by=["Age_band_of_driver"])

# %%
xx
# Out:
#                      Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0     2024-07-25 17:02:00      Monday              18-30          Male
# 6515  2024-07-25 22:00:00    Saturday              18-30          Male
# 6514  2024-07-25 22:00:00    Saturday              18-30          Male
# 6513  2024-07-25 22:00:00    Saturday              18-30          Male
# 6512  2024-07-25 22:00:00    Saturday              18-30          Male
# ...                   ...         ...                ...           ...
# 10125 2024-07-25 05:49:00     Tuesday           Under 18          Male
# 10126 2024-07-25 05:49:00     Tuesday           Under 18          Male
# 11735 2024-07-25 18:56:00      Monday           Under 18          Male
# 10131 2024-07-25 18:39:00   Wednesday           Under 18          Male
# 9681  2024-07-25 20:00:00      Sunday           Under 18          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# ...

# %%
x = df[["Time"	,"Number_of_vehicles_involved"	,"Number_of_casualties"]]

# %%
xc = x.corr()

# %%
sns.heatmap(xc,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
import matplotlib.pyplot as plt

# Histogram for Age_band_of_driver and Type_of_vehicle

plt.figure(figsize=(10, 6))
sns.histplot(xx, kde=True, bins=20, color='blue')
plt.title('No of vehicles vs. no of casualties')
plt.xlabel('Age_band_of_driver')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
df.plot.scatter(title="Age_band_of_driver vs. Accident_severity",x="Age_band_of_driver",y="Accident_severity")
# Out:
# <Axes: title={'center': 'Age_band_of_driver vs. Accident_severity'}, xlabel='Age_band_of_driver', ylabel='Accident_severity'>

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
sns.violinplot(df)
# Out:
# <Axes: >

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
sns.barplot(x=df["Driving_experience"],y=df["Age_band_of_driver"])
# Out:
# <Axes: xlabel='Driving_experience', ylabel='Age_band_of_driver'>

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
